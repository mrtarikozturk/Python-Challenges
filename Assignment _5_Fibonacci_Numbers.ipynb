# %%
fibo = []
n = int(input('Kac elemanli fibonacci dizisi olusturmak istediginizi giriniz: '))

for i in (range(n)):
    if i == 0:
        fibo.append(1)
    elif i == 1:
        fibo.append(1)
    else:
        fibo.append(fibo[-1] + fibo[-2])
print(fibo)
# Out:
# Kac elemanli fibonacci dizisi olusturmak istediginizi giriniz: 5
# [1, 1, 2, 3, 5]
